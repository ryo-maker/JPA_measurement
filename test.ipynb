# %%
import numpy as np
att = str(8.0)
minV = str(0.0)
maxV = str(0.24)
h = [att, minV, maxV]
m = [["ATT", "minV", "maxV"]]
m.append(h)
print(m)
# Out:
# [['ATT', 'minV', 'maxV'], ['8.0', '0.0', '0.24']]

# %%
# import numpy as np

# # csvname ='C:Users/super/Desktop/RyoyaOhashi_C/failed/20220523_8-15dB_0.0-0.1V/20220523_8dB_0.01V.csv'
# csvname ='H:/マイドライブ/RyoyaOhashi/JPA_tools/JPA_Result/failed/20220523_211346_10-15dB_0.0-0.1V/20220523_10dB_0.0V.csv'

# att = str(8.0)
# minV = str(0.0)
# maxV = str(0.24)
# h = [att, minV, maxV]
# m = [["ATT", "minV", "maxV"]]
# m.append(h)
# str_m = str(m)
# print(str_m, type(str_m))

# with open(csvname) as f:
#     l = f.read()
#     # l = f.readlines()
#     # print(type(l))
#     a = str_m + l
#     # print(l)
#     print(a)

# # np.savetxt(csvname, a)

# # l[1:1] = str_m
# # l[1:1] = h

# # l.insert(0, m + '\n' )
# # l.insert(0, 1 + '\n' )
# # l.insert(1, d["minV"] + '\n')
# # l.insert(2, d["maxV"] + '\n')

# # with open(csvname, mode='w') as f:
# #     f.writelines(l)
# #     # writer.writerow(l)
    
# # with open(csvname, 'r') as f:
# #     print(f.read())
# # f.close()
# Out:
# [['ATT', 'minV', 'maxV'], ['8.0', '0.0', '0.24']] <class 'str'>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-07ff71c72038> in <module>
#      13 print(str_m, type(str_m))
#      14
# ---> 15 with open(csvname) as f:
#      16     l = f.read()
#      17     # l = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'H:/マイドライブ/RyoyaOhashi/JPA_tools/JPA_Result/failed/20220523_211346_10-15dB_0.0-0.1V/20220523_10dB_0.0V.csv'

# %%
# with open(csvname, 'r') as f:
#     print(f.read())
# # f.close()
# Out:
# FIRST
# MS46122B
# FIRST
# !2045301/20342287
# !2022/05/23.21:02:42
# !CHANNEL.1
# !TR.MEASUREMENT
# !RF.CORRECTION.OFF
# !AVERAGING.OFF
# !IF.BANDWIDTH: 10HZ
# !NUMBER.OF.TRACES: 2
# !TRACE:       ,TRACE.1           ,TRACE.2
# !PARAMETER:   ,S21               ,S21
# !PORT:        ,PORT1             ,PORT1
# !GRAPH:       ,POLAR.LOG.PHASE   ,LOGMAG.PHASE
# !SMOOTHING:   ,OFF               ,OFF
# !TIMEDOMAIN:  ,NOT.INSTALLED     ,NOT.INSTALLED
# !SWEEPTYPE: FREQ.SWEEP(Linear)
# PNT,FREQ1.GHZ,LOGMAG1,PHASE1.DEG,FREQ2.GHZ,LOGMAG2,PHASE2.DEG
# 1,9.500000000,-9.361378E+001,-107.9270000,9.500000000,-9.361378E+001,-107.9270000
# 2,9.500750000,-9.515964E+001,-114.8474000,9.500750000,-9.515964E+001,-114.8474000
# 3,9.501500000,-9.328724E+001,-108.1834000,9.501500000,-9.328724E+001,-108.1834000
# 4,9.502250000,-9.227315E+001,-107.2634000,9.502250000,-9.227315E+001,-107.2634000
# 5,9.503000000,-9.407588E+001,-114.4995000,9.503000000,-9.407588E+001,-114.4995000
# ...

# %%
# import pandas as pd
# import numpy as np


# csvname ='H:/マイドライブ/RyoyaOhashi/JPA_tools/JPA_Result/failed/20220523_211346_10-15dB_0.0-0.1V/a20220523_10dB_0.0V.csv'

# # これをカラム名にする
# col_names = ('A', 'B', 'C', 'D')
# df = pd.read_csv(csvname, sep=',',  names=col_names, usecols=[0,1,2,3])
# df = df.astype(str)
# print(pd.DataFrame(df), df.dtypes)

# att = str(8.0)
# minV = str(0.0)
# maxV = str(0.24)
# vlt = np.linspace(0.24, 0.0, 0.2)
# # a = ['ATT', 'minV', 'maxV']
# # aa = list()
# # a.append(aa)
# # print(a)
# df_AB = pd.DataFrame({
#     'A':['ATT', 'minV', 'maxV', 'vlt'], 
#     'B':[att, minV, maxV, vlt],
    

#     # 'A':[8,9,10],
#     # 'B':[8,9,10],
#     # 'C':[8,9,10],
#     # 'D':[8,9,10]
# })
# # df_AB = df_AB.astype(str)
# print(pd.DataFrame(df_AB), df_AB.dtypes)
# df_C = pd.concat([df, df_AB])
# print(df_C)
# df_C.to_csv(csvname)

# # print(df.iat[17,1], df.iat[2017,1])
# all_freq = df.iloc[17:,1]
# freq_start = all_freq.head(1)
# freq_end = all_freq.tail(1)
# # print(all_freq, freq_start, freq_end)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-87fb8ec92895> in <module>
#       7 # これをカラム名にする
#       8 col_names = ('A', 'B', 'C', 'D')
# ----> 9 df = pd.read_csv(csvname, sep=',',  names=col_names, usecols=[0,1,2,3])
#      10 df = df.astype(str)
#      11 print(pd.DataFrame(df), df.dtypes)
#
# ...

# %%
import pandas as pd
import numpy as np


csvname ='H:/マイドライブ/RyoyaOhashi/JPA_tools/JPA_Result/failed/20220523_211346_10-15dB_0.0-0.1V/20220523_10dB_0.04V.csv'

# これをカラム名にする
# col_names = ('A', 'B', 'C', 'D')
# df = pd.read_csv(csvname, sep=',',  names=col_names, usecols=[0,1,2,3])
df = pd.read_csv(csvname, sep=',', usecols=[0,1,2,3])
# df = df.astype(str)
# print(pd.DataFrame(df), df.dtypes)

att = str(8.0)
minV = str(0.0)
maxV = str(0.24)
# vlt = np.linspace(0.24, 0.0, 0.2)
dv = 0.02
# a = ['ATT', 'minV', 'maxV']
# aa = list()
# a.append(aa)
# print(a)
df_AB = pd.DataFrame({
    'A':['ATT', 'minV', 'maxV', 'dv'], 
    'B':[att, minV, maxV, dv],
    # 'C':['ATT', 'minV', 'maxV'], 
    # 'D':['ATT', 'minV', 'maxV']

    # 'A':[8,9,10],
    # 'B':[8,9,10],
    # 'C':[8,9,10],
    # 'D':[8,9,10]
})
# df_AB = df_AB.astype(str)
# print(pd.DataFrame(df_AB), df_AB.dtypes)
df_C = pd.concat([df, df_AB], axis = 1)
print(df_C)
df_C.to_csv(csvname, header=False, index=False)

# print(df.iat[17,1], df.iat[2017,1])
all_freq = df.iloc[17:,1]
freq_start = all_freq.head(1)
freq_end = all_freq.tail(1)
# print(all_freq, freq_start, freq_end)
# Out:
#                   MS46122B Unnamed: 1 Unnamed: 2 Unnamed: 3     A     B
# 0        !2045301/20342287        NaN        NaN        NaN   ATT   8.0
# 1     !2022/05/23.21:14:56        NaN        NaN        NaN  minV   0.0
# 2               !CHANNEL.1        NaN        NaN        NaN  maxV  0.24
# 3          !TR.MEASUREMENT        NaN        NaN        NaN    dv  0.02
# 4       !RF.CORRECTION.OFF        NaN        NaN        NaN   NaN   NaN
# ...                    ...        ...        ...        ...   ...   ...
# 2018                  minV        0.0       minV       minV   NaN   NaN
# 2019                  maxV       0.24       maxV       maxV   NaN   NaN
# 2020                   ATT        8.0        ATT        ATT   NaN   NaN
# 2021                  minV        0.0       minV       minV   NaN   NaN
# 2022                  maxV       0.24       maxV       maxV   NaN   NaN
#
# [2023 rows x 6 columns]
